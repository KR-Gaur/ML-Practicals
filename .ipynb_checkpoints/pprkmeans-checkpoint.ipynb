# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import copy

# %%
df = pd.read_csv("Mall_Customers.csv")

# %%
df1 = df.iloc[:,3:5]
df1.iloc[:,:].max()[1]
# Out:
# 99

# %%
#df1.iloc[:,0        ]

# %%
k=6
centroids={}
for i in range(k):
    centroids[i+1]=[np.random.randint(0,df1.iloc[:,:].max()[0]),np.random.randint(0,df1.iloc[:,:].max()[1])]

# %%
centroids
# Out:
# {1: [115, 79], 2: [11, 71], 3: [78, 60], 4: [103, 89], 5: [80, 60], 6: [3, 43]}

# %%
plt.scatter(df1.iloc[:,0],df1.iloc[:,1])

# %%
#plt.scatter(df1['Annual Income (k$)'],df1['Spending Score (1-100)'],color='k')

# %%
cmap={1:'r',2:'b',3:'g',4:'c',5:'y',6:'k'}
for i in centroids.keys():
    plt.scatter(*centroids[i],color=cmap[i])

# %%
def assignment(df1,centroids):
    for i in centroids.keys():
        df1['distance_from_{}'.format(i)]=np.sqrt((centroids[i][0]-df1['Annual Income (k$)'])**2+
                                                 (centroids[i][1]-df1.['Spending Score (1-100)'])**2)
        centroids_distance_col=['distance_from_{}'.format(i) for i in centroids.keys()]
        df1['closest'] = df1.loc[:,centroids_distance_col].idxmin(axis=1)
        df1['closest'] = df1['closest'].map(lambda x:int(x.lstrip('distance_from_')))
        df1['color'] = df1['closest'].map(lambda x:cmap[x])
    return df1

# %%
def update(k):
    for i in centroids.keys():
        centroids[i][0] = np.mean(df1[df1['closest']==i]['Annual Income (k$)'])
        centroids[i][1] = np.mean(df1[df1['closest']==i]['Spending Score (1-100)'])
    return k

# %%
centroids
# Out:
# {1: [115, 79], 2: [11, 71], 3: [78, 60], 4: [103, 89], 5: [80, 60], 6: [3, 43]}

# %%
#old = df1['closest'].copy(deep=True)
df1 = assignment(df1,centroids)
centroids = update(centroids)

# %%
centroids
# Out:
# {1: [nan, nan],
#  2: [nan, nan],
#  3: [62.72727272727273, 50.3],
#  4: [99.88888888888889, 50.638888888888886],
#  5: [81.0, 49.0],
#  6: [27.96153846153846, 49.73076923076923]}

# %%
#df1 = assignment(df1,centroids)
df1
# Out:
#      Annual Income (k$)  Spending Score (1-100)  distance_from_1  closest  \
# 0                    15                      39       118.726577        6
# 1                    15                      81       118.726577        6
# 2                    16                       6       117.345643        6
# 3                    16                      77       117.345643        6
# 4                    17                      40       115.965512        6
# 5                    17                      76       115.965512        6
# 6                    18                       6       114.586212        6
# 7                    18                      94       114.586212        6
# 8                    19                       3       113.207774        6
# 9                    19                      72       113.207774        6
# 10                   19                      14       113.207774        6
# 11                   19                      99       113.207774        6
# 12                   20                      15       111.830228        6
# 13                   20                      77       111.830228        6
# 14                   20                      13       111.830228        6
# 15                   20                      79       111.830228        6
# 16                   21                      35       110.453610        6
# 17                   21                      66       110.453610        6
# 18                   23                      29       107.703296        6
# 19                   23                      98       107.703296        6
# 20                   24                      35       106.329676        6
# 21                   24                      73       106.329676        6
# 22                   25                       5       104.957134        6
# 23                   25                      73       104.957134        6
# 24                   28                      14       100.846418        6
# 25                   28                      82       100.846418        6
# 26                   28                      32       100.846418        6
# 27                   28                      61       100.846418        6
# 28                   29                      31        99.478641        6
# 29                   29                      87        99.478641        6
# ..                  ...                     ...              ...      ...
# 170                  87                      13        29.120440        4
# 171                  87                      75        29.120440        4
# 172                  87                      10        29.120440        4
# 173                  87                      92        29.120440        4
# 174                  88                      13        28.460499        4
# 175                  88                      86        28.460499        4
# 176                  88                      15        28.460499        4
# 190     c        97.406365        49.739320        14.000000        48.764741
# 191     c        97.406365        49.739320        14.000000        48.764741
# 192     c       110.308658        63.513778        26.000000        62.433965
# 193     c       110.308658        63.513778        26.000000        62.433965
# 194     c       119.507322        73.239334        35.355339        72.111026
# 195     c       119.507322        73.239334        35.355339        72.111026
# 196     c       127.475488        81.608823        43.566042        80.448741
# 197     c       127.475488        81.608823        43.566042        80.448741
# 198     c       142.239235        97.005155        58.821765        95.801879
# 199     c       142.239235        97.005155        58.821765        95.801879
#
#      distance_from_6
# 0          30.463092
# 1          30.463092
# 2          29.966648
# 3          29.966648
# 4          29.529646
# 5          29.529646
# 6          29.154759
# 7          29.154759
# 8          28.844410
# 9          28.844410
# 10         28.844410
# 11         28.844410
# 12         28.600699
# 13         28.600699
# 14         28.600699
# 15         28.600699
# 16         28.425341
# 17         28.425341
# 18         28.284271
# 19         28.284271
# 20         28.319605
# 21         28.319605
# 22         28.425341
# 23         28.425341
# 24         29.154759
# 25         29.154759
# 26         29.154759
# 27         29.154759
# 28         29.529646
# 29         29.529646
# ..               ...
# 170        94.826157
# 171        94.826157
# 172        94.826157
# 173        94.826157
# 174        96.176920
# 175        96.176920
# 176        96.176920
# 177        96.176920
# 178       102.956301
# 179       102.956301
# 180       108.406642
# 181       108.406642
# 182       109.772492
# 183       109.772492
# 184       111.139552
# 185       111.139552
# 186       113.877127
# 187       113.877127
# 188       116.619038
# 189       116.619038
# 190       116.619038
# 191       116.619038
# 192       130.384048
# 193       130.384048
# 194       140.064271
# 195       140.064271
# 196       148.384635
# 197       148.384635
# 198       163.682620
# 199       163.682620
#
# [200 rows x 10 columns]

# %%
#plt.scatter(df1.iloc[:,0],df1.iloc[:,1],color=df1['color'])
#df1.iloc[:,3]

# %%
df1 = assignment(df1,centroids)

while True:
    old = df1['closest'].copy(deep=True)
    centroids = update(centroids)    
    ax = plt.axes()
    plt.scatter(df1['Annual Income (k$)'],df1['Spending Score (1-100)'],alpha=0.4)
    for i in centroids.keys():
        plt.scatter(*centroids[i], color=cmap[i])
    plt.xlim(0, 137)
    plt.ylim(0, 137)
    df1 = assignment(df1,centroids)   
    if old.equals(df1['closest']):
        break

# %%
df1.head()
# Out:
#    Annual Income (k$)  Spending Score (1-100)  distance_from_1  closest color  \
# 0                  15                      39              NaN        6     k
# 1                  15                      81              NaN        6     k
# 2                  16                       6              NaN        6     k
# 3                  16                      77              NaN        6     k
# 4                  17                      40              NaN        6     k
#
#    distance_from_2  distance_from_3  distance_from_4  distance_from_5  \
# 0              NaN        52.983596       100.258921        71.630388
# 1              NaN        52.983596       100.258921        71.630388
# 2              NaN        51.572305        98.962051        70.268147
# 3              NaN        51.572305        98.962051        70.268147
# 4              NaN        50.161178        97.668439        68.908000
#
#    distance_from_6
# 0        36.641921
# 1        36.641921
# 2        35.367646
# 3        35.367646
# 4        34.104404

# %%
df1 = assignment(df1,centroids)

# %%
df1.head()
# Out:
#    Annual Income (k$)  Spending Score (1-100)  distance_from_1  closest color  \
# 0                  15                      39        58.523500        3     g
# 1                  15                      81        58.523500        3     g
# 2                  16                       6        57.245087        3     g
# 3                  16                      77        57.245087        3     g
# 4                  17                      40        55.973208        3     g
#
#    distance_from_2  distance_from_3  distance_from_4  distance_from_5
# 0        54.561891        18.601075       101.202767       109.836242
# 1        54.561891        18.601075       101.202767       109.836242
# 2        53.150729        18.867962       100.019998       108.452755
# 3        53.150729        18.867962       100.019998       108.452755
# 4        51.739733        19.235384        98.843310       107.070071
